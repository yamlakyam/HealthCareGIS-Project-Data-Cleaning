# %%
ls

# %%
import os
import pandas as pd

# %%
def read_and_clean_data(file_path):
    df = pd.read_csv(file_path)
    df.dropna(inplace=True)
    df['Date'] = pd.to_datetime(df['Date'])
    
    return df

# %%
import pandas as pd

def format_merged_df(merged_df, pollutant):
    aqs_parameter_desc = merged_df.iloc[0]['AQS_PARAMETER_DESC']

    county_point_data = merged_df.groupby(['STATE', 'COUNTY', 'Site ID','SITE_LATITUDE', 'SITE_LONGITUDE']).agg({
        'DAILY_AQI_VALUE': ['mean', 'min', 'max']}).reset_index()

    county_point_data.columns = [ 'STATE', 'COUNTY','Site ID', 'SITE_LATITUDE', 'SITE_LONGITUDE', 'Mean_AQI', 'Min_AQI', 'Max_AQI']

    county_point_data['Mean_AQI'] = county_point_data['Mean_AQI'].round().astype(int)
    county_point_data['AQS_PARAMETER_DESC'] = aqs_parameter_desc
    
    if pollutant == 'CO':
        county_point_data.columns = ['STATE','COUNTY', 'Site ID', 'SITE_LATITUDE', 'SITE_LONGITUDE', 'Mean_CO_AQI', 'Min_CO_AQI', 'Max_CO_AQI', 'AQS_PARAMETER_DESC']
    elif pollutant == 'SO2':
        county_point_data.columns = ['STATE', 'COUNTY', 'Site ID', 'SITE_LATITUDE', 'SITE_LONGITUDE', 'Mean_SO2_AQI', 'Min_SO2_AQI', 'Max_SO2_AQI', 'AQS_PARAMETER_DESC']
    elif pollutant == 'NO2':
        county_point_data.columns = ['STATE', 'COUNTY', 'Site ID', 'SITE_LATITUDE', 'SITE_LONGITUDE', 'Mean_NO2_AQI', 'Min_NO2_AQI', 'Max_NO2_AQI', 'AQS_PARAMETER_DESC']
    elif pollutant == 'PM10':
        county_point_data.columns = ['STATE', 'COUNTY', 'Site ID', 'SITE_LATITUDE', 'SITE_LONGITUDE', 'Mean_PM10_AQI', 'Min_PM10_AQI', 'Max_PM10_AQI', 'AQS_PARAMETER_DESC']
    elif pollutant == 'PM2.5':
        county_point_data.columns = ['STATE', 'COUNTY', 'Site ID', 'SITE_LATITUDE', 'SITE_LONGITUDE', 'Mean_PM2.5_AQI', 'Min_PM2.5_AQI', 'Max_PM2.5_AQI', 'AQS_PARAMETER_DESC']
    county_point_data = county_point_data.sort_values(by=['STATE','COUNTY'])
    county_point_data.reset_index(drop=True, inplace=True)
    county_point_df = pd.DataFrame(county_point_data)
    return county_point_df

# %% [markdown]
# # Data Processing for CO

# %%
co_folder_path = 'CO/'

co_cleaned_dfs = []

for file_name in os.listdir(co_folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(co_folder_path, file_name)
        cleaned_df = read_and_clean_data(file_path)
        co_cleaned_dfs.append(cleaned_df)

# %%
co_merged_df = pd.concat(co_cleaned_dfs, ignore_index=True)

# %%
co_merged_df
# Out:
#             Date Source    Site ID  POC  Daily Max 8-hour CO Concentration  \
# 0     2021-01-01    AQS   10730023    2                                0.2
# 1     2021-01-02    AQS   10730023    2                                0.2
# 2     2021-01-03    AQS   10730023    2                                0.5
# 3     2021-01-04    AQS   10730023    2                                0.6
# 4     2021-01-05    AQS   10730023    2                                0.4
# ...          ...    ...        ...  ...                                ...
# 85699 2021-12-27    AQS  560391013    1                                0.1
# 85700 2021-12-28    AQS  560391013    1                                0.1
# 85701 2021-12-29    AQS  560391013    1                                0.1
# 85702 2021-12-30    AQS  560391013    1                                0.1
# 85703 2021-12-31    AQS  560391013    1                                0.1
#
#       UNITS  DAILY_AQI_VALUE  \
# 0       ppm                2
# 1       ppm                2
# 2       ppm                6
# 3       ppm                7
# 4       ppm                5
# ...     ...              ...
# 85699   ppm                1
# 85700   ppm                1
# 85701   ppm                1
# 85702   ppm                1
# 85703   ppm                1
#
#                                                Site Name  DAILY_OBS_COUNT  \
# 0                                       North Birmingham               19
# 1                                       North Birmingham               24
# 2                                       North Birmingham               24
# 3                                       North Birmingham               24
# 4                                       North Birmingham               18
# ...                                                  ...              ...
# 85699  Yellowstone National Park - Old Faithful Snow ...               24
# 85700  Yellowstone National Park - Old Faithful Snow ...               24
# 85701  Yellowstone National Park - Old Faithful Snow ...               24
# 85702  Yellowstone National Park - Old Faithful Snow ...               24
# 85703  Yellowstone National Park - Old Faithful Snow ...               24
#
#        PERCENT_COMPLETE  AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE  \
# 0                  79.0               42101    Carbon monoxide    13820.0
# 1                 100.0               42101    Carbon monoxide    13820.0
# 2                 100.0               42101    Carbon monoxide    13820.0
# 3                 100.0               42101    Carbon monoxide    13820.0
# 4                  75.0               42101    Carbon monoxide    13820.0
# ...                 ...                 ...                ...        ...
# 85699             100.0               42101    Carbon monoxide    27220.0
# 85700             100.0               42101    Carbon monoxide    27220.0
# 85701             100.0               42101    Carbon monoxide    27220.0
# 85702             100.0               42101    Carbon monoxide    27220.0
# 85703             100.0               42101    Carbon monoxide    27220.0
#
#                    CBSA_NAME  STATE_CODE    STATE  COUNTY_CODE     COUNTY  \
# 0      Birmingham-Hoover, AL           1  Alabama           73  Jefferson
# 1      Birmingham-Hoover, AL           1  Alabama           73  Jefferson
# 2      Birmingham-Hoover, AL           1  Alabama           73  Jefferson
# 3      Birmingham-Hoover, AL           1  Alabama           73  Jefferson
# 4      Birmingham-Hoover, AL           1  Alabama           73  Jefferson
# ...                      ...         ...      ...          ...        ...
# 85699         Jackson, WY-ID          56  Wyoming           39      Teton
# 85700         Jackson, WY-ID          56  Wyoming           39      Teton
# 85701         Jackson, WY-ID          56  Wyoming           39      Teton
# 85702         Jackson, WY-ID          56  Wyoming           39      Teton
# 85703         Jackson, WY-ID          56  Wyoming           39      Teton
#
#        SITE_LATITUDE  SITE_LONGITUDE
# 0          33.553056      -86.815000
# 1          33.553056      -86.815000
# 2          33.553056      -86.815000
# 3          33.553056      -86.815000
# 4          33.553056      -86.815000
# ...              ...             ...
# 85699      44.373056     -110.830833
# 85700      44.373056     -110.830833
# 85701      44.373056     -110.830833
# 85702      44.373056     -110.830833
# 85703      44.373056     -110.830833
#
# [85704 rows x 20 columns]

# %%
co_df = format_merged_df(co_merged_df, 'CO')
co_df
# Out:
#          STATE                COUNTY    Site ID  SITE_LATITUDE  \
# 0      Alabama             Jefferson   10730023      33.553056
# 1      Alabama             Jefferson   10731003      33.485556
# 2      Alabama             Jefferson   10732059      33.521427
# 3       Alaska             Anchorage   20200018      61.205861
# 4       Alaska  Fairbanks North Star   20900034      64.845690
# ..         ...                   ...        ...            ...
# 252  Wisconsin                 Dodge  550270001      43.466110
# 253  Wisconsin               Kenosha  550590019      42.504720
# 254  Wisconsin             Milwaukee  550790056      42.932570
# 255    Wyoming               Laramie  560210100      41.182227
# 256    Wyoming                 Teton  560391013      44.373056
#
#      SITE_LONGITUDE  Mean_CO_AQI  Min_CO_AQI  Max_CO_AQI AQS_PARAMETER_DESC
# 0        -86.815000            4           1          11    Carbon monoxide
# 1        -86.915000            4           0          14    Carbon monoxide
# 2        -86.844112            6           1          14    Carbon monoxide
# 3       -149.824602            6           1          25    Carbon monoxide
# 4       -147.727413            5           0          20    Carbon monoxide
# ..              ...          ...         ...         ...                ...
# 252      -88.621110            2           0           6    Carbon monoxide
# 253      -87.809300            2           1           5    Carbon monoxide
# 254      -87.934340            4           1          10    Carbon monoxide
# 255     -104.778334            1           0           3    Carbon monoxide
# 256     -110.830833            1           1           7    Carbon monoxide
#
# [257 rows x 9 columns]

# %%
co_df.to_csv('cleaned_CO_data.csv', index=False)

# %% [markdown]
# # **Data Processing for NO2**

# %%
No2_folder_path = 'NO2/'

No2_cleaned_dfs = []

for file_name in os.listdir(No2_folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(No2_folder_path, file_name)
        cleaned_df = read_and_clean_data(file_path)
        No2_cleaned_dfs.append(cleaned_df)

# %%
No2_merged_df = pd.concat(No2_cleaned_dfs, ignore_index=True)
No2_merged_df
# Out:
#              Date Source    Site ID  POC  Daily Max 1-hour NO2 Concentration  \
# 0      2021-01-01    AQS   10730023    1                                23.2
# 1      2021-01-02    AQS   10730023    1                                 9.8
# 2      2021-01-03    AQS   10730023    1                                29.7
# 3      2021-01-04    AQS   10730023    1                                27.9
# 4      2021-01-05    AQS   10730023    1                                31.5
# ...           ...    ...        ...  ...                                 ...
# 140100 2021-12-27    AQS  560391013    1                                 2.0
# 140101 2021-12-28    AQS  560391013    1                                 2.3
# 140102 2021-12-29    AQS  560391013    1                                 2.5
# 140103 2021-12-30    AQS  560391013    1                                 2.4
# 140104 2021-12-31    AQS  560391013    1                                 2.9
#
#        UNITS  DAILY_AQI_VALUE  \
# 0        ppb               22
# 1        ppb                8
# 2        ppb               27
# 3        ppb               25
# 4        ppb               29
# ...      ...              ...
# 140100   ppb                2
# 140101   ppb                2
# 140102   ppb                2
# 140103   ppb                2
# 140104   ppb                2
#
#                                                 Site Name  DAILY_OBS_COUNT  \
# 0                                        North Birmingham               24
# 1                                        North Birmingham               24
# 2                                        North Birmingham               24
# 3                                        North Birmingham               24
# 4                                        North Birmingham               21
# ...                                                   ...              ...
# 140100  Yellowstone National Park - Old Faithful Snow ...               22
# 140101  Yellowstone National Park - Old Faithful Snow ...               24
# 140102  Yellowstone National Park - Old Faithful Snow ...               24
# 140103  Yellowstone National Park - Old Faithful Snow ...               22
# 140104  Yellowstone National Park - Old Faithful Snow ...               24
#
#         PERCENT_COMPLETE  AQS_PARAMETER_CODE      AQS_PARAMETER_DESC  \
# 0                  100.0               42602  Nitrogen dioxide (NO2)
# 1                  100.0               42602  Nitrogen dioxide (NO2)
# 2                  100.0               42602  Nitrogen dioxide (NO2)
# 3                  100.0               42602  Nitrogen dioxide (NO2)
# 4                   88.0               42602  Nitrogen dioxide (NO2)
# ...                  ...                 ...                     ...
# 140100              92.0               42602  Nitrogen dioxide (NO2)
# 140101             100.0               42602  Nitrogen dioxide (NO2)
# 140102             100.0               42602  Nitrogen dioxide (NO2)
# 140103              92.0               42602  Nitrogen dioxide (NO2)
# 140104             100.0               42602  Nitrogen dioxide (NO2)
#
#         CBSA_CODE              CBSA_NAME  STATE_CODE    STATE  COUNTY_CODE  \
# 0         13820.0  Birmingham-Hoover, AL           1  Alabama           73
# 1         13820.0  Birmingham-Hoover, AL           1  Alabama           73
# 2         13820.0  Birmingham-Hoover, AL           1  Alabama           73
# 3         13820.0  Birmingham-Hoover, AL           1  Alabama           73
# 4         13820.0  Birmingham-Hoover, AL           1  Alabama           73
# ...           ...                    ...         ...      ...          ...
# 140100    27220.0         Jackson, WY-ID          56  Wyoming           39
# 140101    27220.0         Jackson, WY-ID          56  Wyoming           39
# 140102    27220.0         Jackson, WY-ID          56  Wyoming           39
# 140103    27220.0         Jackson, WY-ID          56  Wyoming           39
# 140104    27220.0         Jackson, WY-ID          56  Wyoming           39
#
#            COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0       Jefferson      33.553056      -86.815000
# 1       Jefferson      33.553056      -86.815000
# 2       Jefferson      33.553056      -86.815000
# 3       Jefferson      33.553056      -86.815000
# 4       Jefferson      33.553056      -86.815000
# ...           ...            ...             ...
# 140100      Teton      44.373056     -110.830833
# 140101      Teton      44.373056     -110.830833
# 140102      Teton      44.373056     -110.830833
# 140103      Teton      44.373056     -110.830833
# 140104      Teton      44.373056     -110.830833
#
# [140105 rows x 20 columns]

# %%
No2_df = format_merged_df(No2_merged_df, 'NO2')
No2_df
# Out:
#        STATE      COUNTY    Site ID  SITE_LATITUDE  SITE_LONGITUDE  \
# 0    Alabama   Jefferson   10730023      33.553056      -86.815000
# 1    Alabama   Jefferson   10732059      33.521427      -86.844112
# 2    Arizona    Maricopa   40130019      33.483780     -112.142560
# 3    Arizona    Maricopa   40133002      33.457970     -112.046590
# 4    Arizona    Maricopa   40134011      33.369850     -112.620680
# ..       ...         ...        ...            ...             ...
# 412  Wyoming  Sweetwater  560370023      41.556430     -109.530440
# 413  Wyoming  Sweetwater  560370025      41.905400     -109.850000
# 414  Wyoming  Sweetwater  560370200      41.677667     -108.024835
# 415  Wyoming  Sweetwater  560370300      41.750556     -109.788333
# 416  Wyoming       Teton  560391013      44.373056     -110.830833
#
#      Mean_NO2_AQI  Min_NO2_AQI  Max_NO2_AQI      AQS_PARAMETER_DESC
# 0              18            3           42  Nitrogen dioxide (NO2)
# 1              20            5           47  Nitrogen dioxide (NO2)
# 2              29            7           52  Nitrogen dioxide (NO2)
# 3              32            6           57  Nitrogen dioxide (NO2)
# 4              17            4           38  Nitrogen dioxide (NO2)
# ..            ...          ...          ...                     ...
# 412            16            1           32  Nitrogen dioxide (NO2)
# 413             3            1            8  Nitrogen dioxide (NO2)
# 414             9            0           39  Nitrogen dioxide (NO2)
# 415             3            0           18  Nitrogen dioxide (NO2)
# 416             3            0           35  Nitrogen dioxide (NO2)
#
# [417 rows x 9 columns]

# %%
No2_df.to_csv('cleaned_NO2_data.csv', index=False)

# %% [markdown]
# # Data Processing for PM2.5

# %%
PM2_5_folder_path = 'PM2.5/'
PM2_5_cleaned_dfs = []

for file_name in os.listdir(PM2_5_folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(PM2_5_folder_path, file_name)
        cleaned_df = read_and_clean_data(file_path)
        PM2_5_cleaned_dfs.append(cleaned_df)

# %%
PM2_5_merged_df = pd.concat(PM2_5_cleaned_dfs, ignore_index=True)
PM2_5_merged_df
# Out:
#              Date Source      Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0      2021-01-01    AQS   10030010.0  1.0                             6.4
# 1      2021-01-07    AQS   10030010.0  1.0                             5.7
# 2      2021-01-13    AQS   10030010.0  1.0                            11.0
# 3      2021-01-16    AQS   10030010.0  1.0                             5.1
# 4      2021-01-19    AQS   10030010.0  1.0                            12.7
# ...           ...    ...          ...  ...                             ...
# 383968 2021-12-27    AQS  560391013.0  1.0                             2.2
# 383969 2021-12-28    AQS  560391013.0  1.0                             2.5
# 383970 2021-12-29    AQS  560391013.0  1.0                             1.5
# 383971 2021-12-30    AQS  560391013.0  1.0                             1.5
# 383972 2021-12-31    AQS  560391013.0  1.0                             3.4
#
#            UNITS  DAILY_AQI_VALUE  \
# 0       ug/m3 LC             27.0
# 1       ug/m3 LC             24.0
# 2       ug/m3 LC             46.0
# 3       ug/m3 LC             21.0
# 4       ug/m3 LC             52.0
# ...          ...              ...
# 383968  ug/m3 LC              9.0
# 383969  ug/m3 LC             10.0
# 383970  ug/m3 LC              6.0
# 383971  ug/m3 LC              6.0
# 383972  ug/m3 LC             14.0
#
#                                                 Site Name  DAILY_OBS_COUNT  \
# 0                                       FAIRHOPE, Alabama              1.0
# 1                                       FAIRHOPE, Alabama              1.0
# 2                                       FAIRHOPE, Alabama              1.0
# 3                                       FAIRHOPE, Alabama              1.0
# 4                                       FAIRHOPE, Alabama              1.0
# ...                                                   ...              ...
# 383968  Yellowstone National Park - Old Faithful Snow ...              1.0
# 383969  Yellowstone National Park - Old Faithful Snow ...              1.0
# 383970  Yellowstone National Park - Old Faithful Snow ...              1.0
# 383971  Yellowstone National Park - Old Faithful Snow ...              1.0
# 383972  Yellowstone National Park - Old Faithful Snow ...              1.0
#
#         PERCENT_COMPLETE  AQS_PARAMETER_CODE        AQS_PARAMETER_DESC  \
# 0                  100.0             88101.0  PM2.5 - Local Conditions
# 1                  100.0             88101.0  PM2.5 - Local Conditions
# 2                  100.0             88101.0  PM2.5 - Local Conditions
# 3                  100.0             88101.0  PM2.5 - Local Conditions
# 4                  100.0             88101.0  PM2.5 - Local Conditions
# ...                  ...                 ...                       ...
# 383968             100.0             88101.0  PM2.5 - Local Conditions
# 383969             100.0             88101.0  PM2.5 - Local Conditions
# 383970             100.0             88101.0  PM2.5 - Local Conditions
# 383971             100.0             88101.0  PM2.5 - Local Conditions
# 383972             100.0             88101.0  PM2.5 - Local Conditions
#
#         CBSA_CODE                  CBSA_NAME  STATE_CODE    STATE  \
# 0         19300.0  Daphne-Fairhope-Foley, AL         1.0  Alabama
# 1         19300.0  Daphne-Fairhope-Foley, AL         1.0  Alabama
# 2         19300.0  Daphne-Fairhope-Foley, AL         1.0  Alabama
# 3         19300.0  Daphne-Fairhope-Foley, AL         1.0  Alabama
# 4         19300.0  Daphne-Fairhope-Foley, AL         1.0  Alabama
# ...           ...                        ...         ...      ...
# 383968    27220.0             Jackson, WY-ID        56.0  Wyoming
# 383969    27220.0             Jackson, WY-ID        56.0  Wyoming
# 383970    27220.0             Jackson, WY-ID        56.0  Wyoming
# 383971    27220.0             Jackson, WY-ID        56.0  Wyoming
# 383972    27220.0             Jackson, WY-ID        56.0  Wyoming
#
#         COUNTY_CODE   COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0               3.0  Baldwin      30.497478      -87.880258
# 1               3.0  Baldwin      30.497478      -87.880258
# 2               3.0  Baldwin      30.497478      -87.880258
# 3               3.0  Baldwin      30.497478      -87.880258
# 4               3.0  Baldwin      30.497478      -87.880258
# ...             ...      ...            ...             ...
# 383968         39.0    Teton      44.373056     -110.830833
# 383969         39.0    Teton      44.373056     -110.830833
# 383970         39.0    Teton      44.373056     -110.830833
# 383971         39.0    Teton      44.373056     -110.830833
# 383972         39.0    Teton      44.373056     -110.830833
#
# [383973 rows x 20 columns]

# %%
PM2_5_df = format_merged_df(PM2_5_merged_df, 'PM2.5')
PM2_5_df
# Out:
#         STATE      COUNTY      Site ID  SITE_LATITUDE  SITE_LONGITUDE  \
# 0     Alabama     Baldwin   10030010.0      30.497478      -87.880258
# 1     Alabama      DeKalb   10491003.0      34.288567      -85.969858
# 2     Alabama      Etowah   10550010.0      33.988210      -85.992556
# 3     Alabama   Jefferson   10730023.0      33.553056      -86.815000
# 4     Alabama   Jefferson   10731005.0      33.331111      -87.003611
# ...       ...         ...          ...            ...             ...
# 1086  Wyoming    Sheridan  560331003.0      44.782750     -106.964320
# 1087  Wyoming  Sweetwater  560370007.0      41.592536     -109.220852
# 1088  Wyoming  Sweetwater  560370023.0      41.556430     -109.530440
# 1089  Wyoming       Teton  560391006.0      43.457760     -110.797990
# 1090  Wyoming       Teton  560391013.0      44.373056     -110.830833
#
#       Mean_PM2.5_AQI  Min_PM2.5_AQI  Max_PM2.5_AQI        AQS_PARAMETER_DESC
# 0                 30           10.0           58.0  PM2.5 - Local Conditions
# 1                 31           10.0           77.0  PM2.5 - Local Conditions
# 2                 34            6.0           77.0  PM2.5 - Local Conditions
# 3                 35           12.0           75.0  PM2.5 - Local Conditions
# 4                 35           11.0           80.0  PM2.5 - Local Conditions
# ...              ...            ...            ...                       ...
# 1086              15            9.0           25.0  PM2.5 - Local Conditions
# 1087              27            2.0          112.0  PM2.5 - Local Conditions
# 1088              13            2.0           78.0  PM2.5 - Local Conditions
# 1089              19            0.0          118.0  PM2.5 - Local Conditions
# 1090              18            0.0          131.0  PM2.5 - Local Conditions
#
# [1091 rows x 9 columns]

# %%
PM2_5_df.to_csv('cleaned_PM2_5_data.csv', index=False)

# %% [markdown]
# # Data Processing for PM10

# %%
PM10_folder_path = 'PM10/'

# %%
PM10_cleaned_dfs = []

for file_name in os.listdir(PM10_folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(PM10_folder_path, file_name)
        cleaned_df = read_and_clean_data(file_path)
        PM10_cleaned_dfs.append(cleaned_df)

# %%
PM10_merged_df = pd.concat(PM10_cleaned_dfs, ignore_index=True)
PM10_merged_df
# Out:
#              Date Source    Site ID  POC  Daily Mean PM10 Concentration  \
# 0      2021-01-01    AQS   10730023    4                             11
# 1      2021-01-02    AQS   10730023    4                             10
# 2      2021-01-03    AQS   10730023    4                              6
# 3      2021-01-04    AQS   10730023    4                             22
# 4      2021-01-05    AQS   10730023    4                             18
# ...           ...    ...        ...  ...                            ...
# 146207 2021-12-27    AQS  560410201    1                              4
# 146208 2021-12-28    AQS  560410201    1                              4
# 146209 2021-12-29    AQS  560410201    1                              4
# 146210 2021-12-30    AQS  560410201    1                              4
# 146211 2021-12-31    AQS  560410201    1                              3
#
#            UNITS  DAILY_AQI_VALUE         Site Name  DAILY_OBS_COUNT  \
# 0       ug/m3 SC               10  North Birmingham                1
# 1       ug/m3 SC                9  North Birmingham                1
# 2       ug/m3 SC                6  North Birmingham                1
# 3       ug/m3 SC               20  North Birmingham                1
# 4       ug/m3 SC               17  North Birmingham                1
# ...          ...              ...               ...              ...
# 146207  ug/m3 SC                4   Haystack Upwind                1
# 146208  ug/m3 SC                4   Haystack Upwind                1
# 146209  ug/m3 SC                4   Haystack Upwind                1
# 146210  ug/m3 SC                4   Haystack Upwind                1
# 146211  ug/m3 SC                3   Haystack Upwind                1
#
#         PERCENT_COMPLETE  AQS_PARAMETER_CODE     AQS_PARAMETER_DESC  \
# 0                  100.0               81102  PM10 Total 0-10um STP
# 1                  100.0               81102  PM10 Total 0-10um STP
# 2                  100.0               81102  PM10 Total 0-10um STP
# 3                  100.0               81102  PM10 Total 0-10um STP
# 4                  100.0               81102  PM10 Total 0-10um STP
# ...                  ...                 ...                    ...
# 146207             100.0               81102  PM10 Total 0-10um STP
# 146208             100.0               81102  PM10 Total 0-10um STP
# 146209             100.0               81102  PM10 Total 0-10um STP
# 146210             100.0               81102  PM10 Total 0-10um STP
# 146211             100.0               81102  PM10 Total 0-10um STP
#
#         CBSA_CODE              CBSA_NAME  STATE_CODE    STATE  COUNTY_CODE  \
# 0         13820.0  Birmingham-Hoover, AL           1  Alabama           73
# 1         13820.0  Birmingham-Hoover, AL           1  Alabama           73
# 2         13820.0  Birmingham-Hoover, AL           1  Alabama           73
# 3         13820.0  Birmingham-Hoover, AL           1  Alabama           73
# 4         13820.0  Birmingham-Hoover, AL           1  Alabama           73
# ...           ...                    ...         ...      ...          ...
# 146207    21740.0           Evanston, WY          56  Wyoming           41
# 146208    21740.0           Evanston, WY          56  Wyoming           41
# 146209    21740.0           Evanston, WY          56  Wyoming           41
# 146210    21740.0           Evanston, WY          56  Wyoming           41
# 146211    21740.0           Evanston, WY          56  Wyoming           41
#
#            COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0       Jefferson      33.553056      -86.815000
# 1       Jefferson      33.553056      -86.815000
# 2       Jefferson      33.553056      -86.815000
# 3       Jefferson      33.553056      -86.815000
# 4       Jefferson      33.553056      -86.815000
# ...           ...            ...             ...
# 146207      Uinta      41.408699     -110.702153
# 146208      Uinta      41.408699     -110.702153
# 146209      Uinta      41.408699     -110.702153
# 146210      Uinta      41.408699     -110.702153
# 146211      Uinta      41.408699     -110.702153
#
# [146212 rows x 20 columns]

# %%
PM10_df = format_merged_df(PM10_merged_df, 'PM10')
PM10_df
# Out:
#        STATE      COUNTY    Site ID  SITE_LATITUDE  SITE_LONGITUDE  \
# 0    Alabama   Jefferson   10730023      33.553056      -86.815000
# 1    Alabama   Jefferson   10731010      33.545278      -86.549167
# 2    Alabama   Jefferson   10732003      33.499722      -86.924167
# 3    Alabama   Jefferson   10736002      33.578333      -86.773889
# 4    Alabama   Jefferson   10736004      33.565278      -86.796389
# ..       ...         ...        ...            ...             ...
# 551  Wyoming  Sweetwater  560371414      41.521672     -108.662222
# 552  Wyoming  Sweetwater  560371868      41.647036     -108.632466
# 553  Wyoming       Teton  560391006      43.457760     -110.797990
# 554  Wyoming       Uinta  560410200      41.407517     -110.678433
# 555  Wyoming       Uinta  560410201      41.408699     -110.702153
#
#      Mean_PM10_AQI  Min_PM10_AQI  Max_PM10_AQI     AQS_PARAMETER_DESC
# 0               21             6            55  PM10 Total 0-10um STP
# 1               13             4            30  PM10 Total 0-10um STP
# 2               17             5            49  PM10 Total 0-10um STP
# 3               19             2            52  PM10 Total 0-10um STP
# 4               20             5            91  PM10 Total 0-10um STP
# ..             ...           ...           ...                    ...
# 551             13             0           123  PM10 Total 0-10um STP
# 552             16             4           147  PM10 Total 0-10um STP
# 553             14             1            81  PM10 Total 0-10um STP
# 554             11             1            60  PM10 Total 0-10um STP
# 555             11             2            60  PM10 Total 0-10um STP
#
# [556 rows x 9 columns]

# %%
PM10_df.to_csv('cleaned_PM10_data.csv', index=False)

# %% [markdown]
# # Data Processing for SO2

# %%
So2_folder_path = 'SO2/'

# %%
So2_cleaned_dfs = []

for file_name in os.listdir(So2_folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(So2_folder_path, file_name)
        cleaned_df = read_and_clean_data(file_path)
        So2_cleaned_dfs.append(cleaned_df)

# %%
So2_merged_df = pd.concat(So2_cleaned_dfs, ignore_index=True)
So2_merged_df
# Out:
#              Date Source    Site ID  POC  Daily Max 1-hour SO2 Concentration  \
# 0      2021-01-01    AQS   10730023    2                                 0.6
# 1      2021-01-02    AQS   10730023    2                                 2.6
# 2      2021-01-03    AQS   10730023    2                                 0.5
# 3      2021-01-04    AQS   10730023    2                                 3.0
# 4      2021-01-05    AQS   10730023    2                                 2.4
# ...           ...    ...        ...  ...                                 ...
# 131254 2021-12-27    AQS  560370300    1                                 0.4
# 131255 2021-12-28    AQS  560370300    1                                 0.2
# 131256 2021-12-29    AQS  560370300    1                                 1.1
# 131257 2021-12-30    AQS  560370300    1                                 0.1
# 131258 2021-12-31    AQS  560370300    1                                 0.1
#
#        UNITS  DAILY_AQI_VALUE         Site Name  DAILY_OBS_COUNT  \
# 0        ppb                0  North Birmingham               24
# 1        ppb                3  North Birmingham               24
# 2        ppb                0  North Birmingham               24
# 3        ppb                4  North Birmingham               24
# 4        ppb                3  North Birmingham               21
# ...      ...              ...               ...              ...
# 131254   ppb                0         Moxa Arch               24
# 131255   ppb                0         Moxa Arch               24
# 131256   ppb                1         Moxa Arch               22
# 131257   ppb                0         Moxa Arch               24
# 131258   ppb                0         Moxa Arch               24
#
#         PERCENT_COMPLETE  AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE  \
# 0                  100.0               42401     Sulfur dioxide    13820.0
# 1                  100.0               42401     Sulfur dioxide    13820.0
# 2                  100.0               42401     Sulfur dioxide    13820.0
# 3                  100.0               42401     Sulfur dioxide    13820.0
# 4                   88.0               42401     Sulfur dioxide    13820.0
# ...                  ...                 ...                ...        ...
# 131254             100.0               42401     Sulfur dioxide    40540.0
# 131255             100.0               42401     Sulfur dioxide    40540.0
# 131256              92.0               42401     Sulfur dioxide    40540.0
# 131257             100.0               42401     Sulfur dioxide    40540.0
# 131258             100.0               42401     Sulfur dioxide    40540.0
#
#                     CBSA_NAME  STATE_CODE    STATE  COUNTY_CODE      COUNTY  \
# 0       Birmingham-Hoover, AL           1  Alabama           73   Jefferson
# 1       Birmingham-Hoover, AL           1  Alabama           73   Jefferson
# 2       Birmingham-Hoover, AL           1  Alabama           73   Jefferson
# 3       Birmingham-Hoover, AL           1  Alabama           73   Jefferson
# 4       Birmingham-Hoover, AL           1  Alabama           73   Jefferson
# ...                       ...         ...      ...          ...         ...
# 131254       Rock Springs, WY          56  Wyoming           37  Sweetwater
# 131255       Rock Springs, WY          56  Wyoming           37  Sweetwater
# 131256       Rock Springs, WY          56  Wyoming           37  Sweetwater
# 131257       Rock Springs, WY          56  Wyoming           37  Sweetwater
# 131258       Rock Springs, WY          56  Wyoming           37  Sweetwater
#
#         SITE_LATITUDE  SITE_LONGITUDE
# 0           33.553056      -86.815000
# 1           33.553056      -86.815000
# 2           33.553056      -86.815000
# 3           33.553056      -86.815000
# 4           33.553056      -86.815000
# ...               ...             ...
# 131254      41.750556     -109.788333
# 131255      41.750556     -109.788333
# 131256      41.750556     -109.788333
# 131257      41.750556     -109.788333
# 131258      41.750556     -109.788333
#
# [131259 rows x 20 columns]

# %%
So2_df = format_merged_df(So2_merged_df, 'SO2')
So2_df
# Out:
#        STATE                COUNTY    Site ID  SITE_LATITUDE  SITE_LONGITUDE  \
# 0    Alabama             Jefferson   10730023      33.553056      -86.815000
# 1    Alabama             Jefferson   10731003      33.485556      -86.915000
# 2    Alabama                Mobile   10970003      30.770181      -88.087761
# 3    Alabama                Shelby   11179001      33.092800      -86.807200
# 4     Alaska  Fairbanks North Star   20900034      64.845690     -147.727413
# ..       ...                   ...        ...            ...             ...
# 387  Wyoming               Fremont  560130004      43.024210     -108.363700
# 388  Wyoming               Laramie  560210100      41.182227     -104.778334
# 389  Wyoming            Sweetwater  560370023      41.556430     -109.530440
# 390  Wyoming            Sweetwater  560370025      41.905400     -109.850000
# 391  Wyoming            Sweetwater  560370300      41.750556     -109.788333
#
#      Mean_SO2_AQI  Min_SO2_AQI  Max_SO2_AQI AQS_PARAMETER_DESC
# 0               2            0           20     Sulfur dioxide
# 1               1            0           13     Sulfur dioxide
# 2               2            0           21     Sulfur dioxide
# 3               6            0          107     Sulfur dioxide
# 4              12            0           59     Sulfur dioxide
# ..            ...          ...          ...                ...
# 387             1            0           17     Sulfur dioxide
# 388             1            0           16     Sulfur dioxide
# 389             0            0           29     Sulfur dioxide
# 390             1            0            9     Sulfur dioxide
# 391             1            0           85     Sulfur dioxide
#
# [392 rows x 9 columns]

# %%
So2_df.to_csv('cleaned_So2_data.csv', index=False)
